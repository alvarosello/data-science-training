# %% [markdown]
# <a href="https://colab.research.google.com/github/alvarosello/data-science-training/blob/main/Estatura_promedio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tarea**
# Calcula la estatura promedio de los olimpistas por año. A continuación, un ejemplo de formato de salida.
# ![Screen_Shot_2020-09-03_at_2.00.56_PM.png](data:image/png;base64,...)
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/Coding Dojo/PTDataScience/PandasParaManipulaciónDeDatos/athleteEventsNoPersonal.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    ID   Age  Height  ...          Sport                               Event Medal
# 0   5  21.0   185.0  ...  Speed Skating    Speed Skating Women's 500 metres   NaN
# 1   5  21.0   185.0  ...  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 2   5  25.0   185.0  ...  Speed Skating    Speed Skating Women's 500 metres   NaN
# 3   5  25.0   185.0  ...  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 4   5  27.0   185.0  ...  Speed Skating    Speed Skating Women's 500 metres   NaN
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40616 entries, 0 to 40615
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      40616 non-null  int64
#  1   Age     39143 non-null  float64
#  2   Height  31615 non-null  float64
#  3   Team    40616 non-null  object
#  4   NOC     40616 non-null  object
#  5   Games   40616 non-null  object
#  6   Year    40616 non-null  int64
#  7   Season  40616 non-null  object
#  8   City    40616 non-null  object
#  9   Sport   40616 non-null  object
#  10  Event   40616 non-null  object
#  11  Medal   5917 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 3.7+ MB

# %%
# Ver en qué filas hay datos faltantes para la columna Age
missing_age = df['Age'].isna()
df.loc[missing_age, :]
# Out:
#            ID  Age  ...                                Event   Medal
# 36         54  NaN  ...             Boxing Men's Heavyweight     NaN
# 38         58  NaN  ...  Cycling Men's Road Race, Individual     NaN
# 39         58  NaN  ...        Cycling Men's Road Race, Team     NaN
# 56        139  NaN  ...              Football Men's Football  Bronze
# 71        173  NaN  ...              Football Men's Football     NaN
# ...       ...  ...  ...                                  ...     ...
# 40437  135070  NaN  ...           Rowing Men's Single Sculls     NaN
# 40442  135081  NaN  ...           Athletics Men's 100 metres     NaN
# 40443  135081  NaN  ...   Athletics Men's 110 metres Hurdles     NaN
# 40450  135107  NaN  ...    Sailing Mixed Two Person Keelboat     NaN
# 40556  135435  NaN  ...  Swimming Men's 100 metres Freestyle     NaN
#
# [1473 rows x 12 columns]

# %%
df.groupby(['ID', 'Year'])[['Height']].mean()
# Out:
#              Height
# ID     Year
# 5      1988   185.0
#        1992   185.0
#        1994   185.0
# 6      1992   188.0
#        1994   188.0
# ...             ...
# 135567 2000   183.0
#        2004   183.0
# 135570 2014   176.0
# 135571 1998   185.0
#        2002   185.0
#
# [28189 rows x 1 columns]
